# %% [markdown]
# # Sample Python Notebook
#
# This is a sample Jupyter notebook demonstrating basic Python code.

# %%
# Simple Python code
print("Hello, World!")

# Basic calculation
result = 2 + 3
print(f"2 + 3 = {result}")

# %% [markdown]
# ## Next Steps
#
# You can add more cells, run code, and explore data here.

# %%
hi
